# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("matches.csv")
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
#1
df['count']=1
t=df.groupby(['season']).size()#count()['count']
print(t[2008])
# Out:
# 58

# %%
#2
df['count']=1
t=df.groupby(['city']).count().sort_values("count")['count']
t
# Out:
# city
# Bloemfontein        2
# Nagpur              3
# Kimberley           3
# East London         3
# Kanpur              4
# Kochi               5
# Raipur              6
# Sharjah             6
# Abu Dhabi           7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Cuttack             7
# Johannesburg        8
# Indore              9
# Dharamsala          9
# Rajkot             10
# Mohali             10
# Ahmedabad          12
# Centurion          12
# Visakhapatnam      13
# Bengaluru          14
# Durban             15
# Pune               38
# Chandigarh         46
# Jaipur             47
# Chennai            57
# Hyderabad          64
# Bangalore          66
# Delhi              74
# Kolkata            77
# Mumbai            101
# Name: count, dtype: int64

# %%
print("max=",t.index[0])
print("min=",t.index[-1])
# Out:
# max= Bloemfontein
# min= Mumbai

# %%
#3
t=df.groupby(['city']).count()['id']
t
# Out:
# city
# Abu Dhabi           7
# Ahmedabad          12
# Bangalore          66
# Bengaluru          14
# Bloemfontein        2
# Cape Town           7
# Centurion          12
# Chandigarh         46
# Chennai            57
# Cuttack             7
# Delhi              74
# Dharamsala          9
# Durban             15
# East London         3
# Hyderabad          64
# Indore              9
# Jaipur             47
# Johannesburg        8
# Kanpur              4
# Kimberley           3
# Kochi               5
# Kolkata            77
# Mohali             10
# Mumbai            101
# Nagpur              3
# Port Elizabeth      7
# Pune               38
# Raipur              6
# Rajkot             10
# Ranchi              7
# Sharjah             6
# Visakhapatnam      13
# Name: id, dtype: int64

# %%
#4
df['count']=1
n=df.groupby(['toss_winner']).count().sort_values("count")['count']
print("min=",n.index[0],"max=",n.index[-1])
# Out:
# min= Rising Pune Supergiant max= Mumbai Indians

# %%
#5
#for Rising Pune Supergiant
f=n.index[0] #for accessing index nave n.iloc[0] for accessinf value stored in the index
mr = df[(df['team1'] == f) | (df['team2'] == f)]
print(mr['toss_decision'])
# Out:
# 1     field
# 3     field
# 8     field
# 12    field
# 16    field
# 24    field
# 27    field
# 28    field
# 32    field
# 37    field
# 39    field
# 42    field
# 50      bat
# 53    field
# 55    field
# 58      bat
# Name: toss_decision, dtype: object

# %%
#for Mumbai Indians
f=n.index[-1]
mr = df[(df['team1'] == f) | (df['team2'] == f)]
print(mr['toss_decision'])
# Out:
# 1      field
# 6      field
# 9      field
# 11     field
# 15     field
#        ...
# 742    field
# 746      bat
# 751    field
# 752      bat
# 755      bat
# Name: toss_decision, Length: 187, dtype: object

# %%
#6
df['count']=1
df.groupby(['result']).count().sort_values('count')['count']
# Out:
# result
# no result      4
# tie            9
# normal       743
# Name: count, dtype: int64

# %%
#7
mf=df[df['result']=='tie']
print(mf[['team1','team2']])
# Out:
#                            team1                        team2
# 33                 Gujarat Lions               Mumbai Indians
# 125             Rajasthan Royals        Kolkata Knight Riders
# 189              Kings XI Punjab          Chennai Super Kings
# 387  Royal Challengers Bangalore          Sunrisers Hyderabad
# 400             Delhi Daredevils  Royal Challengers Bangalore
# 475             Rajasthan Royals        Kolkata Knight Riders
# 535             Rajasthan Royals              Kings XI Punjab
# 705        Kolkata Knight Riders               Delhi Capitals
# 746               Mumbai Indians          Sunrisers Hyderabad

# %%
#8
df.sort_values('win_by_runs')

print("lowest runs=",df['winner'].iloc[0])
print("highest runs=",df['winner'].iloc[-1])
print("Venue for lowest runs=",df['venue'].iloc[0])
print("Venue for highest runs=",df['venue'].iloc[-1])
# Out:
# lowest runs= Sunrisers Hyderabad
# highest runs= Mumbai Indians
# Venue for lowest runs= Rajiv Gandhi International Stadium, Uppal
# Venue for highest runs= Rajiv Gandhi Intl. Cricket Stadium

# %%
#9
df.sort_values('win_by_runs').iloc[0,10]
# Out:
# 'Delhi Daredevils'

# %%
t=df.groupby(['player_of_match']).count().sort_values("count")['count']

t
# Out:
# player_of_match
# A Chandila         1
# M Ur Rahman        1
# MA Starc           1
# MD Mishra          1
# MF Maharoof        1
#                   ..
# RG Sharma         17
# DA Warner         17
# MS Dhoni          17
# AB de Villiers    20
# CH Gayle          21
# Name: count, Length: 226, dtype: int64

# %%
#10
t = df.groupby('player_of_match').size()


t_more = t[t > 3]#more than 3 times


for i in range(0,len(t_more)):
    print(t_more.index[i],"\n")
# Out:
# A Mishra
#
# A Nehra
#
# AB de Villiers
#
# AC Gilchrist
#
# AD Russell
#
# AJ Finch
#
# AM Rahane
#
# AR Patel
#
# AT Rayudu
#
# B Kumar
#
# BB McCullum
#
# BJ Hodge
#
# CA Lynn
#
# CH Gayle
#
# DA Warner
#
# DPMD Jayawardene
#
# DR Smith
#
# DW Steyn
#
# F du Plessis
#
# G Gambhir
#
# GJ Maxwell
#
# HH Pandya
#
# Harbhajan Singh
#
# JC Buttler
#
# JD Unadkat
#
# JH Kallis
#
# JJ Bumrah
#
# JP Duminy
#
# JP Faulkner
#
# KA Pollard
#
# KC Sangakkara
#
# KD Karthik
#
# KH Pandya
#
# KL Rahul
#
# M Vijay
#
# MEK Hussey
#
# MK Pandey
#
# ML Hayden
#
# MS Dhoni
#
# N Rana
#
# NM Coulter-Nile
#
# PA Patel
#
# RA Jadeja
#
# RG Sharma
#
# RR Pant
#
# RV Uthappa
#
# Rashid Khan
#
# S Dhawan
#
# SC Ganguly
#
# SE Marsh
#
# SK Raina
#
# SK Warne
#
# SL Malinga
#
# SP Narine
#
# SPD Smith
#
# SR Tendulkar
#
# SR Watson
#
# SS Iyer
#
# SV Samson
#
# Sandeep Sharma
#
# UT Yadav
#
# V Kohli
#
# V Sehwag
#
# YK Pathan
#
# Yuvraj Singh

# %%
#11
t=df.groupby(['player_of_match']).count().sort_values("count")['count']

t_max=t[-1]

for i, count in t.items():
    if (count==t_max):

        print(i)
# Out:
# CH Gayle
# C:\Users\Debdyuti\AppData\Local\Temp\ipykernel_17264\649040580.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_max=t[-1]

# %%
#12
df.sort_values('win_by_runs',ascending=False).iloc[0,-5]
# Out:
# 'Feroz Shah Kotla'

# %%
#13
df.sort_values('win_by_runs').iloc[0, -5]
# Out:
# 'Rajiv Gandhi International Stadium, Uppal'

# %%
u=df.groupby(['umpire1']).count().sort_values("count")['count']

u_max=t.iloc[-1]
u_max
for i, count in u.items():
    if (count==u_max):

        print(i)

# %%
#14
t= pd.concat([df['umpire1'],df['umpire2']])
#t is  list
t.value_counts().idxmax()
# Out:
# 'S Ravi'

# %%
#15
df['count']=1
t=df.groupby(['season']).count().sort_values("count")['count']
print("total matches played in each season",t)
# Out:
# total matches played in each season season
# 2009    57
# 2008    58
# 2015    59
# 2017    59
# 2010    60
# 2014    60
# 2016    60
# 2018    60
# 2019    60
# 2011    73
# 2012    74
# 2013    76
# Name: count, dtype: int64

# %%
#16
df2=pd.read_csv('deliveries.csv')
df2.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
#16
t = df.groupby('season')['win_by_runs'].sum()
print("total runs in each season",t)
# Out:
# total runs in each season season
# 2008     705
# 2009     764
# 2010     976
# 2011    1098
# 2012     960
# 2013    1241
# 2014     644
# 2015     850
# 2016     676
# 2017     788
# 2018     675
# 2019     665
# Name: win_by_runs, dtype: int64

# %%
#17
df['count']=1
t=df.groupby(['toss_winner']).count().sort_values("count")['count']
print("tosses won by each team",t)
# Out:
# tosses won by each team toss_winner
# Rising Pune Supergiant          6
# Rising Pune Supergiants         7
# Kochi Tuskers Kerala            8
# Delhi Capitals                 10
# Gujarat Lions                  15
# Pune Warriors                  20
# Deccan Chargers                43
# Sunrisers Hyderabad            46
# Delhi Daredevils               80
# Rajasthan Royals               80
# Kings XI Punjab                81
# Royal Challengers Bangalore    81
# Chennai Super Kings            89
# Kolkata Knight Riders          92
# Mumbai Indians                 98
# Name: count, dtype: int64

# %%
#18
t= df.groupby(['season', 'toss_decision']).size().unstack()

# Plot the data as a line graph
t.plot(kind='line', figsize=(8,6), marker='o')
plt.xlabel('Season')
plt.ylabel('Number of Matches')
plt.title('Toss Decision Across Seasons')
plt.xticks(rotation=45)
plt.legend(title='Toss Decision')
plt.grid(True)
plt.show()

# %%
#19
s=df2['dismissal_kind'].value_counts()
labels=s.index
values=s.values

plt.scatter(labels, values)
plt.xticks(rotation=90)
plt.plot(labels,values)

# %%
#20
t20=df2.groupby(['batsman']).sum()['total_runs']
x1=t20.index[0:10]
y1=t20.values[0:10]
plt.bar(x1,y1)
plt.xticks(rotation=90)
plt.plot(x1,y1)

# %%
#21
t21=df['player_of_match'].value_counts()
x2=t21.index[0:10]
y2=t21.values[0:10]
plt.scatter(x2,y2)
plt.xticks(rotation=90)
plt.plot(x2,y2)

# %%
#22
tot=pd.concat([df['team1'],df['team2']])
tot_matches= tot.value_counts()
print(tot_matches)
# Out:
# Mumbai Indians                 187
# Royal Challengers Bangalore    180
# Kolkata Knight Riders          178
# Kings XI Punjab                176
# Chennai Super Kings            164
# Delhi Daredevils               161
# Rajasthan Royals               147
# Sunrisers Hyderabad            108
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Delhi Capitals                  16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
#24
win_matches=df['winner'].value_counts()
x3=win_matches.index
y3=win_matches.values
plt.scatter(x3,y3)
plt.xticks(rotation=90)
plt.plot(x3,y3)
plt.show()

# %%
#25

ratio=(tot_matches/win_matches)
print(ratio)
# Out:
# Chennai Super Kings            1.640000
# Deccan Chargers                2.586207
# Delhi Capitals                 1.600000
# Delhi Daredevils               2.402985
# Gujarat Lions                  2.307692
# Kings XI Punjab                2.146341
# Kochi Tuskers Kerala           2.333333
# Kolkata Knight Riders          1.934783
# Mumbai Indians                 1.715596
# Pune Warriors                  3.833333
# Rajasthan Royals               1.960000
# Rising Pune Supergiant         1.600000
# Rising Pune Supergiants        2.800000
# Royal Challengers Bangalore    2.142857
# Sunrisers Hyderabad            1.862069
# Name: count, dtype: float64

# %%
#23
plt.scatter(x3,y3)
plt.scatter(tot_matches.index,tot_matches.values)
plt.scatter(ratio.index,ratio.values)
plt.xticks(rotation=90)
plt.plot(x3,y3)
plt.plot(tot_matches.index,tot_matches.values)
plt.plot(ratio.index,ratio.values)

# %%
#26
df['count']=1
df.groupby(['toss_winner','toss_decision']).count()['count']
# Out:
# toss_winner                  toss_decision
# Chennai Super Kings          bat              48
#                              field            41
# Deccan Chargers              bat              24
#                              field            19
# Delhi Capitals               bat               2
#                              field             8
# Delhi Daredevils             bat              29
#                              field            51
# Gujarat Lions                bat               1
#                              field            14
# Kings XI Punjab              bat              26
#                              field            55
# Kochi Tuskers Kerala         bat               3
#                              field             5
# Kolkata Knight Riders        bat              30
#                              field            62
# Mumbai Indians               bat              44
#                              field            54
# ...
